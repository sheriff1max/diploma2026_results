# %% [markdown]
# # MVP-FAS
#
# https://github.com/sheriff1max/MVP-FAS

# %%
def hour2sec(hour: float) -> float:
    return hour * 60 * 60

# %%
PARAMS = {
    'domain': 'figure',  # cutout | figure | mannequin | mask | print | screen
    'description': 'MVP-FAS',
    'direction': 'minimize',

    'n_trials': 500,
    'timeout': hour2sec(6),  # # нужно в секундах
}


_domains = ['cutout', 'figure', 'mannequin', 'mask', 'print', 'screen']
PARAMS['exclude_folders'] = [domain for domain in _domains if domain != PARAMS['domain']]
print(f"{PARAMS['exclude_folders'] = }")

PARAMS['description'] += f' domain={PARAMS["domain"]}'
print(f"{PARAMS['description'] = }")
# Out:
# PARAMS['exclude_folders'] = ['cutout', 'mannequin', 'mask', 'print', 'screen']
# PARAMS['description'] = 'MVP-FAS domain=figure'

# %%
import shutil
# shutil.rmtree('MVP-FAS')
# shutil.rmtree('fas_aug_attack')

# %%
# !git clone https://github.com/sheriff1max/MVP-FAS.git -q

# %%
# !git clone https://github.com/sheriff1max/fas_aug_attack.git -q

# %%
# !pip install yacs -q
# !pip install ftfy -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00

# %%
import sys

path_model = '/kaggle/working/MVP-FAS'
if path_model not in sys.path:
    sys.path.insert(1, path_model)

path_attack = '/kaggle/working/fas_aug_attack'
if path_attack not in sys.path:
    sys.path.insert(1, path_attack)

# %%
import os
import random
import cv2
import numpy as np
from pathlib import Path
from tqdm import tqdm

import torch
from torch.nn import functional as F
import torchvision

import matplotlib.pyplot as plt

from configs.cfg import _C as cfg

from models.make_network import get_network

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
def set_pretrained_setting(net, weight_path, device):
    checkpoint_dict = torch.load(weight_path, device, weights_only=False)
    checkpoint = checkpoint_dict['state_dict']
    last_epoch = checkpoint_dict['epoch'] - 1
    
    pretrained_dict = {k: v for k, v in checkpoint.items() if k in net.module.state_dict().keys()}
    net.module.load_state_dict(pretrained_dict)
    return net, last_epoch


def set_seed(seed, deterministic=False):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    if deterministic:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %%
seed = 42

checkpoint = '/kaggle/input/datasets/morph1max/mvp-fas-weights/MVP-FAS_weights/MVP-FAS_P2_weights/drive-download-20260403T091807Z-3-003/MVP_FAS_P2_S.pth'

set_seed(seed, deterministic=False)

net = get_network(cfg, device, net_name='MVP_FAS')
net, last_epoch = set_pretrained_setting(net, checkpoint, device)
# Out:
# 100%|████████████████████████████████████████| 335M/335M [00:01<00:00, 301MiB/s]
# Finetune layer in backbone: visual.class_embedding
# Finetune layer in backbone: visual.positional_embedding
# Finetune layer in backbone: visual.proj
# Finetune layer in backbone: visual.conv1.weight
# Finetune layer in backbone: visual.ln_pre.weight
# Finetune layer in backbone: visual.ln_pre.bias
# Finetune layer in backbone: visual.transformer.resblocks.0.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.0.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.0.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.0.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.0.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.0.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.0.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.0.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.0.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.0.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.0.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.0.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.1.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.1.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.1.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.1.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.1.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.1.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.1.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.1.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.1.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.1.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.1.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.1.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.2.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.2.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.2.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.2.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.2.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.2.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.2.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.2.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.2.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.2.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.2.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.2.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.3.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.3.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.3.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.3.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.3.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.3.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.3.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.3.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.3.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.3.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.3.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.3.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.4.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.4.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.4.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.4.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.4.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.4.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.4.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.4.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.4.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.4.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.4.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.4.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.5.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.5.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.5.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.5.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.5.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.5.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.5.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.5.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.5.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.5.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.5.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.5.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.6.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.6.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.6.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.6.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.6.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.6.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.6.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.6.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.6.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.6.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.6.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.6.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.7.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.7.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.7.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.7.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.7.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.7.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.7.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.7.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.7.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.7.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.7.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.7.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.8.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.8.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.8.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.8.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.8.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.8.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.8.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.8.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.8.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.8.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.8.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.8.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.9.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.9.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.9.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.9.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.9.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.9.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.9.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.9.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.9.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.9.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.9.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.9.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.10.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.10.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.10.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.10.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.10.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.10.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.10.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.10.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.10.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.10.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.10.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.10.ln_2.bias
# Finetune layer in backbone: visual.transformer.resblocks.11.attn.in_proj_weight
# Finetune layer in backbone: visual.transformer.resblocks.11.attn.in_proj_bias
# Finetune layer in backbone: visual.transformer.resblocks.11.attn.out_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.11.attn.out_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.11.ln_1.weight
# Finetune layer in backbone: visual.transformer.resblocks.11.ln_1.bias
# Finetune layer in backbone: visual.transformer.resblocks.11.mlp.c_fc.weight
# Finetune layer in backbone: visual.transformer.resblocks.11.mlp.c_fc.bias
# Finetune layer in backbone: visual.transformer.resblocks.11.mlp.c_proj.weight
# Finetune layer in backbone: visual.transformer.resblocks.11.mlp.c_proj.bias
# Finetune layer in backbone: visual.transformer.resblocks.11.ln_2.weight
# Finetune layer in backbone: visual.transformer.resblocks.11.ln_2.bias
# Finetune layer in backbone: visual.ln_post.weight
# Finetune layer in backbone: visual.ln_post.bias
# Finetune layer in backbone: transformer.learnable

# %% [markdown]
# # Dataset

# %%
from src.utils.dataset import AttackDataset

dataset = AttackDataset(
    path='/kaggle/input/datasets/morph1max/spoof-attack-liveness-face',
    exclude_folders=PARAMS['exclude_folders'],
)
print(f'Returns keys = {dataset[0].keys()}')
len(dataset)
# Out:
# Returns keys = dict_keys(['img', 'filename', 'path2file', 'is_real', 'type_attack'])
# 42

# %%
# plt.imsave('example.png', dataset[300]['img']);

# %% [markdown]
# # Model

# %%
from src.base import BaseModel
from typing import Any


def get_transform(
    img_size: tuple[int] = (224, 224),
    normalize_mean: list[float] = [0.485, 0.456, 0.406],
    normalize_std: list[float] = [0.229, 0.224, 0.225],
):
    return torchvision.transforms.Compose(
        [
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize(mean=normalize_mean, std=normalize_std),
            torchvision.transforms.Resize(img_size),
        ]
    )

to_tensor = get_transform()


class MVP_FAS_Model(BaseModel):
    def __init__(self, model: Any):
        super().__init__(model=model)

    def predict(self, img: Any) -> float:
        net.eval()
        with torch.no_grad():
            img = to_tensor(img).unsqueeze(0)
            img = img.to(device)
    
            # forward
            val_results = net(img)
            val_output_list = val_results['similarity']

            # metric
            # spoofing | real
            #     0       1

            # Вероятность положительного класса. Нужно максимизировать.
            score = F.softmax(val_output_list, dim=-1).detach().cpu().numpy()[:, -1][0]
            return float(score)

    
model = MVP_FAS_Model(model=net)
pred = model.predict(dataset[0]['img'])
print(pred, type(pred))
# Out:
# 6.167036917759106e-05 <class 'float'>

# %% [markdown]
# # Transforms

# %%
from src import transforms
from src.base import BaseTransform
import inspect

# %%
list_type_transforms = [
    # Advanced transformations
    [
        transforms.MorphologicalTransform,
        None,
    ],

    # Noise transforms
    [
        transforms.PixelDropoutTransform,
        None,
    ],

    # Color transformations
    [
        transforms.BrightnessContrastTransform,
        transforms.HSVTransform,
        transforms.RGBShiftTransform,
        transforms.GammaTransform,
        transforms.SolarizeTransform,
        transforms.PosterizeTransform,
        transforms.EqualizeTransform,
        transforms.InvertTransform,
        transforms.ToGrayTransform,
        transforms.ChannelShuffleTransform,
        transforms.ToSepiaTransform,
        None,
    ],

    # Transformations of blurring and sharpness
    [
        transforms.BlurTransform,
        transforms.GaussianBlurTransform,
        transforms.MedianBlurTransform,
        transforms.MotionBlurTransform,
        transforms.SharpenTransform,
        transforms.EmbossTransform,
        None,
    ],

    # Weather and atmospheric conditions
    [
        transforms.RainTransform,
        transforms.SnowTransform,
        transforms.RainbowTransform,
        transforms.ChromaticAberrationTransform,
        transforms.DefocusTransform,
        transforms.ZoomBlurTransform,
        None,
    ],

    # Geometric transformations
    [
        transforms.PerspectiveTransform,
        transforms.OpticalDistortionTransform,
        transforms.ShiftScaleRotateTransform,
        None,
    ],

    # Transformation of compression and artifacts
    [
        transforms.CompressionTransform,
        transforms.DownscaleTransform,
        None,
    ],

    # Dropout transforms
    [
        transforms.CoarseDropoutTransform,
        transforms.GridDropoutTransform,
        None,
    ],
]


list_type_transforms[:5]
# Out:
# [[src.transforms.transforms.MorphologicalTransform, None],
#  [src.transforms.transforms.PixelDropoutTransform, None],
#  [src.transforms.transforms.BrightnessContrastTransform,
#   src.transforms.transforms.HSVTransform,
#   src.transforms.transforms.RGBShiftTransform,
#   src.transforms.transforms.GammaTransform,
#   src.transforms.transforms.SolarizeTransform,
#   src.transforms.transforms.PosterizeTransform,
#   src.transforms.transforms.EqualizeTransform,
#   src.transforms.transforms.InvertTransform,
#   src.transforms.transforms.ToGrayTransform,
#   src.transforms.transforms.ChannelShuffleTransform,
#   src.transforms.transforms.ToSepiaTransform,
#   None],
#  [src.transforms.transforms.BlurTransform,
#   src.transforms.transforms.GaussianBlurTransform,
#   src.transforms.transforms.MedianBlurTransform,
#   src.transforms.transforms.MotionBlurTransform,
#   src.transforms.transforms.SharpenTransform,
#   src.transforms.transforms.EmbossTransform,
#   None],
#  [src.transforms.transforms.RainTransform,
#   src.transforms.transforms.SnowTransform,
#   src.transforms.transforms.RainbowTransform,
#   src.transforms.transforms.ChromaticAberrationTransform,
#   src.transforms.transforms.DefocusTransform,
#   src.transforms.transforms.ZoomBlurTransform,
#   None]]

# %% [markdown]
# # Pipeline

# %%
from src.pipeline import PipelineAttackOptunaDataset, PipelineAttackOptunaImg
from src.utils.logging import LoggerOptuna

# %%
logger = LoggerOptuna(
    direction=PARAMS['direction'],
    description=PARAMS['description'],
)

# DATASET
optuna_attack_pipeline_dataset = PipelineAttackOptunaDataset(
    model=model,
    list_type_transforms=list_type_transforms,
    logger=logger,
)

optuna_attack_pipeline_dataset.optimize(
    data=dataset,
    direction=PARAMS['direction'],
    n_trials=PARAMS['n_trials'],
    timeout=PARAMS['timeout'],
    show_progress=True,
    catch=(ValueError, ),
)

# IMG
# optuna_attack_pipeline_img = PipelineAttackOptunaImg(
#     model=model,
#     list_type_transforms=list_type_transforms,
#     logger=logger,
# )

# optuna_attack_pipeline_img.optimize(
#     data=dataset[0]['img'],
#     direction=PARAMS['direction'],
#     n_trials=PARAMS['n_trials'],
#     timeout=PARAMS['timeout'],
#     show_progress=True,
#     catch=(ValueError, ),
# )
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (6, 9) automatically adjusted to (7, 9).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (4, 5) automatically adjusted to (5, 5).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (4, 6) automatically adjusted to (5, 7).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (4, 8) automatically adjusted to (5, 9).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (7, 12) automatically adjusted to (7, 13).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (3, 4) automatically adjusted to (3, 5).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (5, 6) automatically adjusted to (5, 7).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (7, 8) automatically adjusted to (7, 9).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (6, 8) automatically adjusted to (7, 9).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (8, 10) automatically adjusted to (9, 11).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (4, 7) automatically adjusted to (5, 7).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (5, 8) automatically adjusted to (5, 9).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (10, 13) automatically adjusted to (11, 13).
#   result = _ensure_odd_values(result, info.field_name)
# /usr/local/lib/python3.12/dist-packages/albumentations/augmentations/blur/functional.py:232: UserWarning: blur_limit: Non-zero kernel sizes must be odd. Range (10, 14) automatically adjusted to (11, 15).
#   result = _ensure_odd_values(result, info.field_name)

# %%
print(os.listdir('/kaggle/working/logs'))
# Out:
# ['run_1']

# %%
# !zip -FSr run.zip /kaggle/working/logs/run_3

# %%
shutil.rmtree('MVP-FAS')
shutil.rmtree('fas_aug_attack')
